# %%
import prince

import sqlite3 as sql
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import plotly.express as px
import prince
from sklearn.preprocessing import OneHotEncoder

# %%
### Define the path to the file (a string in a variable 'db_file')
db_file = '../database/cortona_week.db'

# %%
### Create a connection to the database
# If the database does not exist it will be created
try:
    cn = sql.connect(db_file)

except Exception as e:
    print(e)

# %%
### SQL Queries

#only information from persons are aggregated that have attended the cortona events in question
# (events 1-8 until year 1995)

#This query extracts information from the tabel Person if pk_person is found
#in EITHER the table Study OR the table Pursuit
q_persons = """
SELECT
    p.pk_person,
    p.name,
    p.gender,
    p.birth_date,
    p.nationality
FROM
    Person p
WHERE
    p.pk_person IN (
        SELECT s.fk_person
            FROM Study s
        UNION
        SELECT p2.fk_person
            FROM Pursuit p2
    )
AND
    p.pk_person IN (
        SELECT 
            p4.fk_person
        FROM
            Participation p4
        WHERE
            p4.fk_event < 9
    )
"""
q_all = """
SELECT 
	p2.fk_person,
    o.meta_category,
    NULL,
    o2.meta_category,
    p3.metacategoryCountry
FROM
	Pursuit p2
FULL JOIN
    Organization o
ON
    p2.fk_organization = o.pk_organization

FULL JOIN
    Occupation o2
ON
    p2.fk_occupation = o2.pk_occupation
    
FULL JOIN
    Place p3
ON
    o.fk_place = p3.pk_place

WHERE
    p2.fk_person IN (
        SELECT 
            p4.fk_person
        FROM
            Participation p4
        WHERE
            p4.fk_event < 9
    )

    
UNION
SELECT
    s.fk_person,
    o.meta_category,
    s2.meta_category,
    NULL,
    p3.metacategoryCountry
FROM
    Study s
JOIN
    Subject s2
ON
    s.fk_subject = s2.pk_subject
JOIN
    Organization o
ON
    s.fk_organization = o.pk_organization
JOIN
    Place p3
ON
    o.fk_place = p3.pk_place
WHERE
     s.fk_person IN (
        SELECT 
            p4.fk_person
        FROM
            Participation p4
        WHERE
            p4.fk_event < 12
    )


"""


q_pursuit = """
SELECT 
	p2.fk_person,
    o.meta_category,
    o2.meta_category,
    p3.country
FROM
	Pursuit p2
FULL JOIN
    Organization o
ON
    p2.fk_organization = o.pk_organization

FULL JOIN
    Occupation o2
ON
    p2.fk_occupation = o2.pk_occupation
FULL JOIN
    Place p3
ON
    o.fk_place = p3.pk_place
WHERE
     p2.fk_person IN (
        SELECT 
            p4.fk_person
        FROM
            Participation p4
        WHERE
            p4.fk_event < 9
    )
"""

q_study = """
SELECT
    s.fk_person,
    o.meta_category,
    s2.meta_category,
    p3.country
FROM
    Study s
JOIN
    Subject s2
ON
    s.fk_subject = s2.pk_subject
JOIN
    Organization o
ON
    s.fk_organization = o.pk_organization
JOIN
    Place p3
ON
    o.fk_place = p3.pk_place
WHERE
     s.fk_person IN (
        SELECT 
            p4.fk_person
        FROM
            Participation p4
        WHERE
            p4.fk_event < 12
    )
"""

# %%
### Creates container for results
cur = cn.cursor()
cur

# %%
### Execute the SQL queries and save the results
cur.execute(q_persons)
data_persons = cur.fetchall()

cur.execute(q_pursuit)
data_pursuit= cur.fetchall()

cur.execute(q_study)
data_study = cur.fetchall()

cur.execute(q_all)
data_all= cur.fetchall()

# %%
pd_persons = pd.DataFrame(data_persons, columns = ['pkPerson', 'name','gender','birthDate','nationality'])

pd_pursuit = pd.DataFrame(data_pursuit, columns = ['pkPerson', 'metacategoryOrganization' , 'metacategoryOccupation', 'countryPursuit'])

pd_study = pd.DataFrame (data_study, columns = ['pkPerson','studyMetaCategory','organizationMetacategory','countryStudy'])

pd_pursuit_study = pd.DataFrame(data_all, columns = ['pkPerson', 'metacategoryOrganizationPursuit' ,
                                                     'studyMetaCategory', 'occupationMetacategory','countryPursuitStudy'])



pd_persons=pd_persons.sort_values(by=['pkPerson'])
pd_pursuit=pd_pursuit.sort_values(by=['pkPerson'])
pd_study=pd_study.sort_values(by=['pkPerson'])
pd.set_option('display.max_rows', 500)

display(pd_pursuit_study)
#display(pd_study)


all_person= pd.concat([pd_pursuit['pkPerson'],pd_study['pkPerson']])
all_person=all_person.sort_values()
pd.set_option('display.max_rows', 500)
#display(all_person)

#print(pd_pursuit['pkPerson'].nunique())
#print(pd_study['pkPerson'].nunique())

#print(pd_persons['pkPerson'])
all_person_unique=all_person.unique()

max_persons= pd_persons['pkPerson'].nunique()

not_in_mask= ~pd_persons['pkPerson'].isin(all_person)
#print(not_in_mask)
#print(pd_persons['pkPerson'][not_in_mask])
#print(all_person.nunique())
#print(pd_persons['pkPerson'].nunique())

pd.set_option("display.max_rows", 10)
#display(pd_persons)
#display(pd_pursuit)
#display(pd_study)
# Out:
#      pkPerson metacategoryOrganizationPursuit      studyMetaCategory  \
# 0           1                     Universität                   None
# 1           1                     Universität  Geisteswissenschaften
# 2           3                            None                   None
# 3           3        psychologisches Institut         Psychotherapie
# 4           5                     Universität                   None
# 5           5                     Universität                   None
# 6           5                     Universität  Geisteswissenschaften
# 7           7                            None                   None
# 8          13                            None                   None
# 9          16                            None                   None
# 10         16                     Universität                   None
# 11         18                            None                   None
# 12         18                            None                   None
# 13         19                            None                   None
# 14         19        psychologisches Institut  Geisteswissenschaften
# 15         19        psychologisches Institut         Psychotherapie
# 16         20                            None                   None
# 17         22                            None                   None
# 18         22                     Universität  Geisteswissenschaften
# 19         24                            None                   None
# 20         25                           Firma                   None
# 21         27                            None                   None
# 22         27                            None                   None
# 23         27                     Universität                Medizin
# 24         27        psychologisches Institut                   None
# 25         27        psychologisches Institut                   None
# 26         27        psychologisches Institut         Psychotherapie
# 27         30                            None                   None
# 28         30                     Universität                   None
# 29         30                     Universität          Spiritualität
# 30         30        psychologisches Institut                   None
# 31         30        psychologisches Institut                   None
# 32         30        psychologisches Institut         Psychotherapie
# 33         33                     Universität                   None
# 34         33                     Universität    Naturwissenschaften
# 35         33        internationales Netzwerk                   None
# 36         33        internationales Netzwerk                   None
# 37         34                     Universität  Geisteswissenschaften
# 38         34    gegenkulturelle Gemeinschaft                   None
# 39         34    gegenkulturelle Gemeinschaft                   None
# 40         34         spirituelle Vereinigung                   None
# 41         34         spirituelle Vereinigung          Spiritualität
# 42         39                            None                   None
# 43         47    alternative Forschungsinstut                   None
# 44         47    alternative Forschungsinstut                   None
# 45         47    alternative Forschungsinstut  Geisteswissenschaften
# 46         47    gegenkulturelle Gemeinschaft                   None
# 47         47    gegenkulturelle Gemeinschaft                   None
# 48         47        internationales Netzwerk                   None
# 49         50                            None                   None
# 0        Universitätsposten              Europa
# 1                      None              Europa
# 2              Therapeut:in                None
# 3                      None              Europa
# 4        Universitätsposten             Amerika
# 5        Universitätsposten              Europa
# 6                      None              Europa
# 7              Therapeut:in                None
# 8               Künstler:in                None
# 9               Künstler:in                None
# 10       Universitätsposten              Europa
# 11         Seminarleiter:in                None
# 12             Therapeut:in                None
# 13             Therapeut:in                None
# 14                     None              Europa
# 15                     None              Europa
# 16              Künstler:in                None
# 17             Therapeut:in                None
# 18                     None              Europa
# 19             Therapeut:in                None
# 20                Leiter:in              Europa
# 21              Arzt/Ärztin                None
# 22             Therapeut:in                None
# 23                     None              Europa
# 24                Leiter:in              Europa
# 25       Universitätsposten              Europa
# 26                     None              Europa
# 27             Therapeut:in                None
# 28       Universitätsposten              Europa
# 29                     None              Europa
# 30                 Mitglied                None
# 31       Universitätsposten              Europa
# 32                     None              Europa
# 33       Universitätsposten              Europa
# 34                     None             Amerika
# 35                 Mitglied                None
# 36       Universitätsposten                None
# 37                     None              Europa
# 38                 Mitglied                None
# 39       Universitätsposten             Amerika
# 40   spiritueller Leiter:in             Amerika
# 41                     None             Amerika
# 42             Therapeut:in                None
# 43                 Mitglied                None
# 44       Universitätsposten             Amerika
# 45                     None             Amerika
# 46                 Mitglied                None
# 47       Universitätsposten             Amerika
# 48       Universitätsposten                None
# 49              Künstler:in                None
# 50       Universitätsposten                None
# 51                Leiter:in                None
# 52                 Mitglied                None
# 53   spiritueller Leiter:in             Amerika
# 54                     None             Amerika
# 55             Therapeut:in                None
# 56                     None              Europa
# 57                 Mitglied               Asien
# 58          Public official               Asien
# 59       Universitätsposten              Europa
# 60                     None              Europa
# 61            Intellectuals                None
# 62            Intellectuals             Amerika
# 63                 Mitglied                None
# 64       Universitätsposten             Amerika
# 65            Intellectuals                None
# 66                 Mitglied                None
# 67                Heiler:in                None
# 68                Leiter:in              Europa
# 69              Arzt/Ärztin                None
# 70                     None              Europa
# 71                Leiter:in                None
# 72       Universitätsposten             Amerika
# 73             Therapeut:in                None
# 74       Universitätsposten              Europa
# 75               Buddhismus                None
# 76                Leiter:in              Europa
# 77       Universitätsposten             Amerika
# 78       Universitätsposten              Europa
# 79                     None             Amerika
# 80                Leiter:in                None
# 81                 Mitglied                None
# 82       Universitätsposten                None
# 83       Universitätsposten             Amerika
# 84                     None             Amerika
# 85                Leiter:in              Europa
# 86       Universitätsposten              Europa
# 87                     None              Europa
# 88                Leiter:in              Europa
# 89                 Mitglied                None
# 90              Künstler:in                None
# 91              Künstler:in              Europa
# 92                     None              Europa
# 93                 Mitglied                None
# 94                     None              Europa
# 95                     None              Europa
# 96       Universitätsposten                None
# 97              Künstler:in                None
# 98                     None             Amerika
# 99                Leiter:in              Europa
# 100      Universitätsposten              Europa
# 101                    None              Europa
# 102                    None              Europa
# 103             Arzt/Ärztin                None
# 104                    None              Europa
# 105               Heiler:in                None
# 106      Universitätsposten             Amerika
# 107                    None             Amerika
# 108               Leiter:in                None
# 109      Universitätsposten             Amerika
# 110      Universitätsposten                None
# 111             Künstler:in                None
# 112                    None              Europa
# 113             Künstler:in                None
# 114             Künstler:in                None
# 115            Therapeut:in                None
# 116                    None              Europa
# 117            Therapeut:in                None
# 118      Universitätsposten              Europa
# 119                    None              Europa
# 120               Leiter:in                None
# 121      Universitätsposten              Europa
# 122                    None              Europa
# 123                Mitglied              Europa
# 124           Intellectuals              Europa
# 125      Universitätsposten              Europa
# 126                    None              Europa
# 127                Mitglied              Europa
# 128               Leiter:in              Europa
# 129      Universitätsposten              Europa
# 130                    None              Europa
# 131      Universitätsposten                None
# 132      Universitätsposten             Amerika
# 133      Universitätsposten               Asien
# 134                    None             Amerika
# 135                Mitglied                None
# 136      Universitätsposten             Amerika
# 137                Mitglied                None
# 138               Leiter:in              Europa
# 139      Universitätsposten              Europa
# 140                Mitglied                None
# 141             Künstler:in                None
# 142  spiritueller Leiter:in                None
# 143      Universitätsposten              Europa
# 144                    None             Amerika
# 145      Universitätsposten             Amerika
# 146           Intellectuals                None
# 147            Therapeut:in                None
# 148      Universitätsposten              Europa
# 149                    None              Europa
# 150             Künstler:in                None
# 151                    None              Europa
# 152            Therapeut:in                None
# 153            Therapeut:in                None
# 154    redaktioneller Beruf                None
# 155                    None              Europa
# 156    redaktioneller Beruf                None
# 157             Künstler:in                None
# 158                    None              Europa
# 159                Mitglied              Europa
# 160             Künstler:in                None
# 161            Therapeut:in                None
# 162                    None              Europa
# 163               Leiter:in              Europa
# 164                    None              Europa
# 165             Künstler:in                None
# 166                    None              Europa
# 167  spiritueller Leiter:in                None
# 168               Leiter:in              Europa
# 169      Universitätsposten              Europa
# 170                    None              Europa
# 171           Intellectuals                None
# 172         Public official                None
# 173                    None              Europa
# 174             Künstler:in                None
# 175               Leiter:in              Europa
# 176      Universitätsposten              Europa
# 177                    None              Europa
# 178            Therapeut:in                None
# 179              Buddhismus                None
# 180               Leiter:in              Europa
# 181            Therapeut:in                None
# 182                    None              Europa
# 183                    None              Europa
# 184  spiritueller Leiter:in              Europa
# 185            Therapeut:in                None
# 186      Universitätsposten             Amerika
# 187            Therapeut:in                None
# 188      Universitätsposten              Europa
# 189                    None              Europa
# 190      Universitätsposten              Europa
# 191      Universitätsposten              Europa
# 192               Leiter:in              Europa
# 193      Universitätsposten                None
# 194            Therapeut:in                None
# 195    redaktioneller Beruf                None
# 196                    None              Europa
# 197                    None              Europa
# 198               Leiter:in              Europa
# 199      Universitätsposten              Europa
# 200                    None              Europa
# 201      Universitätsposten                None
# 202             Künstler:in                None
# 203               Leiter:in                None
# 204      Universitätsposten             Amerika
# 205                    None             Amerika
# 206          Mitarbeiter:in               Asien
# 207              Management              Europa
# 208                    None              Europa
# 209      Universitätsposten          Australien
# 210                    None              Europa
# 211                    None              Europa
# 212      Universitätsposten                None
# 213                Mitglied              Europa
# 214        Seminarleiter:in                None
# 215                    None              Europa
# 216                Mitglied              Europa
# 217               Leiter:in                None
# 218                    None              Europa
# 219      Universitätsposten              Europa
# 220                    None              Europa
# 221                Mitglied              Europa
# 222          Mitarbeiter:in              Europa
# 223    redaktioneller Beruf                None
# 224                    None             Amerika
# 225                    None              Europa
# 226    redaktioneller Beruf              Europa
# 227             Künstler:in                None
# 228                    None              Europa
# 229               Leiter:in              Europa
# 230    redaktioneller Beruf                None
# 231               Leiter:in                None
# 232      Universitätsposten              Europa
# 233    redaktioneller Beruf                None
# 234      Universitätsposten              Europa
# 235                Mitglied              Europa
# 236                Mitglied                None
# 237               Leiter:in               Asien
# 238      Universitätsposten              Europa
# 239                    None              Europa
# 240               Leiter:in                None
# 241            Therapeut:in                None
# 242      Universitätsposten              Europa
# 243                    None              Europa
# 244               Leiter:in              Europa
# 245                    None              Europa
# 246            Therapeut:in                None
# 247                    None             Amerika
# 248      Universitätsposten             Amerika
# 249               Leiter:in                None
# 250               Leiter:in             Amerika
# 251  spiritueller Leiter:in                None
# 252                    None              Europa
# 253          Mitarbeiter:in              Europa
# 254          Mitarbeiter:in                None
# 255      Universitätsposten              Europa
# 256                    None              Europa
# 257               Leiter:in              Europa
# 258      Universitätsposten              Europa
# 259                    None             Amerika
# 260                    None             Amerika
# 261           Intellectuals                None
# 262            Therapeut:in                None
# 263      Universitätsposten              Europa
# 264                    None              Europa
# 265    redaktioneller Beruf                None
# 266      Universitätsposten              Europa
# 267                    None               Asien
# 268      Universitätsposten              Europa
# 269                    None              Europa
# 270      Universitätsposten              Europa
# 271                    None              Europa
# 272             Künstler:in                None
# 273                    None              Europa
# 274              Management                None
# 275              Management                None
# 276              Management              Europa
# 277                    None              Europa
# 278              Management                None
# 279              Management              Europa
# 280                    None              Europa
# 281                    None              Europa
# 282               Leiter:in              Europa
# 283              Management              Europa
# 284      Universitätsposten              Europa
# 285                    None              Europa
# 286            Therapeut:in                None
# 287    redaktioneller Beruf                None
# 288                    None              Europa
# 289             Künstler:in                None
# 290      Universitätsposten              Europa
# 291               Leiter:in              Europa
# 292      Universitätsposten              Europa
# 293                    None              Europa
# 294               Leiter:in              Europa
# 295      Universitätsposten             Amerika
# 296      Universitätsposten             Amerika
# 297      Universitätsposten              Europa
# 298                    None              Europa
# 299               Leiter:in              Europa
# 300             Künstler:in                None
# 301               Leiter:in              Europa
# 302                Mitglied              Europa
# 303              Management                None
# 304                    None              Europa
# 305      Universitätsposten             Amerika
# 306                    None             Amerika
# 307      Universitätsposten              Europa
# 308                    None              Europa
# 309             Aktivist:in                None
# 310                    None              Europa
# 311               Leiter:in                None
# 312                Mitglied                None
# 313  spiritueller Leiter:in                None
# 314               Leiter:in                None
# 315      Universitätsposten                None
# 316                    None              Europa
# 317            Therapeut:in                None
# 318      Universitätsposten              Europa
# 319                    None              Europa
# 320                Mitglied                None
# 321      Universitätsposten              Europa
# 322                    None              Europa
# 323                Mitglied                None
# 324  spiritueller Leiter:in                None
# 325                    None             Amerika
# 326      Universitätsposten             Amerika
# 327      Universitätsposten                None
# 328              Management              Europa
# 329               Leiter:in              Europa
# 330      Universitätsposten              Europa
# 331                    None              Europa
# 332      Universitätsposten             Amerika
# 333                    None             Amerika
# 334      Universitätsposten                None
# 335                Mitglied             Amerika
# 336               Leiter:in                None
# 337            Therapeut:in                None
# 338               Leiter:in                None
# 339      Universitätsposten              Europa
# 340    redaktioneller Beruf                None
# 341                    None              Europa
# 342      Universitätsposten             Amerika
# 343             Künstler:in                None
# 344              Management                None
# 345                    None              Europa
# 346              Management                None
# 347      Universitätsposten                None
# 348  spiritueller Leiter:in                None
# 349      Universitätsposten             Amerika
# 350                    None             Amerika
# 351           Intellectuals                None
# 352                Mitglied                None
# 353             Künstler:in                None
# 354            Therapeut:in                None
# 355                    None              Europa
# 356      Universitätsposten              Europa
# 357                    None              Europa
# 358  spiritueller Leiter:in                None
# 359      Universitätsposten              Europa
# 360                    None              Europa
# 361               Leiter:in                None
# 362      Universitätsposten              Europa
# 363                    None              Europa
# 364               Leiter:in                None
# 365               Leiter:in              Europa
# 366          Mitarbeiter:in                None
# 367               Leiter:in              Europa
# 368      Universitätsposten              Europa
# 369                    None              Europa
# 370               Leiter:in                None
# 371             Künstler:in                None
# 372    redaktioneller Beruf                None
# 373             Künstler:in                None
# 374               Leiter:in              Europa
# 375                Mitglied                None
# 376      Universitätsposten              Europa
# 377                    None             Amerika
# 378                Mitglied                None
# 379         Public official                None
# 380             Künstler:in                None
# 381  spiritueller Leiter:in                None
# 382      Universitätsposten                None
# 383            Therapeut:in                None
# 384      Universitätsposten              Europa
# 385              Management                None
# 386      Universitätsposten              Europa
# 387                    None             Amerika
# 388                Mitglied                None
# 389        Seminarleiter:in                None
# 390            Therapeut:in                None
# 391               Leiter:in              Europa
# 392            Therapeut:in                None
# 393      Universitätsposten              Europa
# 394                    None              Europa
# 395      Universitätsposten                None
# 396               Leiter:in              Europa
# 397                    None              Europa
# 398               Leiter:in              Europa
# 399                    None             Amerika
# 400               Leiter:in              Europa
# 401      Universitätsposten              Europa
# 402               Leiter:in              Europa
# 403      Universitätsposten              Europa
# 404                    None             Amerika
# 405               Leiter:in                None
# 406               Leiter:in              Europa
# 407                Mitglied              Europa
# 408      Universitätsposten             Amerika
# 409      Universitätsposten              Europa
# 410                    None              Europa
# 411      Universitätsposten              Europa
# 412                    None              Europa
# 413                Mitglied             Amerika

# %%
#one-hot encoding
pd_all_to_encode=pd_pursuit_study[['pkPerson','countryPursuitStudy','occupationMetacategory']]
pd_all_hot_encode=pd.get_dummies(pd_all_to_encode,dummy_na=True)
pd.set_option('display.max_rows', 500)

#display(pd_all_hot_encode)

# %%
grouped_pd_all_hot_encode=pd_all_hot_encode.groupby('pkPerson').sum().reset_index()


#

pd_person_to_encode = pd_persons[['pkPerson','gender']]

pd_person_hot_encode=pd.get_dummies(pd_person_to_encode,dummy_na=False)



output=grouped_pd_all_hot_encode.merge(pd_person_hot_encode, left_on='pkPerson', right_on='pkPerson', how = 'inner')
#display(output)
output = output.loc[:, output.columns != 'pkPerson']
output_full = output.replace({True: 1, False: 0})



mca_no_one_hot = prince.MCA(n_components=8,
    n_iter=3,
    copy=True,
    check_input=True,
    engine='sklearn',
    random_state=42,
    one_hot=False)
mca_no_one_hot = mca_no_one_hot.fit(output_full)
mca_no_one_hot.eigenvalues_summary

mca_no_one_hot.plot(
    output_full,
    x_component=0,
    y_component=1,
    show_column_markers=True,
    show_row_markers=True,
    show_column_labels=False,
    show_row_labels=False
)
#mca_no_one_hot.eigenvalues_summary
# Out:
# /tmp/ipykernel_127/3712199734.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   output_full = output.replace({True: 1, False: 0})
# alt.LayerChart(...)

# %%
#one-hot encoding

#leave birth_date out for now
pd_person_to_encode = pd_persons[['pkPerson','gender', 'nationality']]

pd_person_hot_encode=pd.get_dummies(pd_person_to_encode,dummy_na=False)

pd_study_hot_encode=pd.get_dummies(pd_study,dummy_na=False)
#display(pd_study_hot_encode)

grouped_pd_study_hot_encode=pd_study_hot_encode.groupby('pkPerson').sum().reset_index()
#display(grouped_pd_study_hot_encode)

pd_pursuit_hot_encode=pd.get_dummies(pd_pursuit,dummy_na=False)
#display(pd_pursuit_hot_encode)

grouped_pd_pursuit_hot_encode=pd_pursuit_hot_encode.groupby('pkPerson').sum().reset_index()
#display(grouped_pd_pursuit_hot_encode)





output=pd_pursuit_hot_encode.merge(grouped_pd_study_hot_encode, left_on='pkPerson', right_on='pkPerson', how = 'inner')
pd.set_option("display.max_columns", 30)
pd.set_option("display.max_rows", 35)
#display(output)

#grouped_output=output.groupby('pkPerson').sum().reset_index()
#display(grouped_output)
#output_full=output.merge(pd_person_hot_encode, left_on='pkPerson', right_on='pkPerson', how='outer')
#display(output_full)
#output_full_encoded=pd.get_dummies(output_full,dummy_na=True)
#display(output_full_encoded)

output=output.fillna(0)
output = output.replace({True: 1, False: 0})
output=output.groupby('pkPerson').sum().reset_index()


output_full=output.merge(pd_person_hot_encode, left_on='pkPerson', right_on='pkPerson', how='inner')
output_full=output_full.fillna(0)
output_full = output_full.replace({True: 1, False: 0})
output_full=output_full.groupby('pkPerson').sum().reset_index()
output_full=output_full.astype('float')

pd.set_option("display.max_columns", 5)
pd.set_option("display.max_rows", 5)

is_infinite = np.isinf(output_full.values)

# Check if any infinity values exist
res = is_infinite.any()
print(res)
is_nan = np.isnan(output_full.values)

# Check if any nan values exist
res = is_nan.any()
print(res)


output_full[output_full > 1] = 1
pd.set_option("display.max_columns", 5)
pd.set_option("display.max_rows", 5)
#display(output_full)
#output_full = output_full.replace({1: True, 0: False})
output_full = output_full.loc[:, output_full.columns != 'pkPerson']
#display(output_full)
output_full.to_csv('output_for_MCA.csv',index=True) 


print(output_full.columns[output_full.sum(axis=0)==0])
print(np.sum(output_full.sum(axis=1)==0)) 

print(np.sum(output_full.sum(axis=0)==0)) 

output_full_dropped = output_full.drop(columns=output_full.columns[output_full.sum(axis=0)==0])


mca_no_one_hot = prince.MCA(one_hot=False)
mca_no_one_hot = mca_no_one_hot.fit(output_full_dropped)


mca_no_one_hot.plot(
    output_full_dropped,
    x_component=0,
    y_component=1,
    show_column_markers=True,
    show_row_markers=True,
    show_column_labels=False,
    show_row_labels=False
)
#test_study=pd.get_dummies(pd_study,dummy_na=True)
#display(test_study)
# Out:
# /tmp/ipykernel_120/1800673234.py:36: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   output = output.replace({True: 1, False: 0})
# /tmp/ipykernel_120/1800673234.py:42: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   output_full = output_full.replace({True: 1, False: 0})
# False
# False
# Index(['metacategoryOrganization_künstlerischer Ort',
#        'metacategoryOccupation_Public official',
#        'metacategoryOccupation_redaktioneller Beruf', 'countryPursuit_Indien',
#        'countryPursuit_Japan', 'countryPursuit_Slowenien',
#        'organizationMetacategory_künstlerischer Ort', 'nationality_Frankreich',
#        'nationality_Indien', 'nationality_Irland', 'nationality_Kuba',
#        'nationality_Luxemburg', 'nationality_Palästina',
#        'nationality_Slowenien', 'nationality_Tibet'],
#       dtype='object')
# 0
# 15
# alt.LayerChart(...)
